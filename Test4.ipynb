# %%
import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.5/7.5 MB 2.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 470.9/470.9 kB 5.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 5.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 98.3/98.3 kB 937.2 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\79992\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 293.3/293.3 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./kc_house_data.csv', sep=",", encoding="windows-1251")
df.sample(n=10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 1131   4039100400  20150506T000000  515000.0         3       2.50
# 19884  6791400070  20150126T000000  350000.0         3       2.50
# 16201  2487200680  20150224T000000  447000.0         2       1.00
# 4340   5101404563  20140627T000000  561500.0         3       1.75
# 6351   8648100130  20150429T000000  306500.0         3       2.50
# 3127   3828000405  20150116T000000  176500.0         3       1.00
# 18765  3009800015  20150422T000000  502501.0         2       1.00
# 868    3330500875  20141226T000000  381156.0         2       1.00
# 5604   3243100080  20150501T000000  270000.0         3       1.00
# 17201  1552800280  20140918T000000  298950.0         5       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1131          3000      8250     1.0           0     0  ...      8
# 19884         2040     13590     2.0           0     0  ...      8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize = (6,4))
plt.hist(df['price'], bins = 15); 
plt.title('Динамика стоимости домов')
plt.xlabel('Стоимость домов')
plt.ylabel('Количество домов');

# %%
plt.figure(figsize=(6,8))

plt.hist(df['price'], bins=100)
plt.title('Динамика стоимости домов')
plt.xlabel('Стоимость дома')
plt.ylabel('Количество домов');

# %% [markdown]
# Больше всего домов продается стоимостью до от 300000 до 7000000 у.е.

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(10,10))

plt.hist(df['sqft_living'], bins=100)
plt.title('Динамика распределения жилой площади домов')
plt.xlabel('Жилая площадь дома')
plt.ylabel('Количество домов');

# %% [markdown]
# Больше всего домов продается с жилой площадью примерно от 1700 кв.м. до 2200 кв.м.

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(16,8))

plt.hist(df['yr_built'], bins=100)
plt.title('Динамика распределения года постройки домов')
plt.xlabel('Год постройки дома')
plt.ylabel('Количество домов');

# %% [markdown]
# До 1945 года наблюдается кризис в постройке домов. Больше всего домов было построено в 1975, 2008, 2014 годах.

# %% [markdown]
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы

# %%
data_view = df['waterfront'].value_counts()
val = data_view.values
plt.pie(val,labels=['seaview', 'w/o seaviews'],explode=[0,0.3],
        radius = 1.5, startangle=60,
        labeldistance=1.2, autopct='%.1f%%');

# %% [markdown]
# 99,2 % домов не имеют вид на набережную , а 0,8 % домов имеют вид на набережную.

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
df.floors.max(), df.floors.min()
# Out:
# (3.5, 1.0)

# %%
data2 = df['floors'].value_counts(normalize=True) * 100
data2
# Out:
# floors
# 1.0    49.414704
# 2.0    38.129829
# 1.5     8.837274
# 3.0     2.836256
# 2.5     0.744922
# 3.5     0.037015
# Name: proportion, dtype: float64

# %%
data_floor = df['floors'].value_counts()
f_val = data_floor.values
f_ind = data_floor.index
plt.figure(figsize=(12, 6))
plt.bar(f_ind,f_val, width=0.4, facecolor='c', alpha=0.75)
plt.title('Распределение этажности домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
explode = [0.0, 0.1, 0.3, 0.5, 0.5, 0.5]
plt.pie(data2.values, autopct='%1.2f%%', labels=data2.index, explode=explode)
plt.legend(data2.index)
plt.title('Распределение этажей домов');

# %% [markdown]
# Больше всего домов имеют 1 и 2 этажа. Лидируют по продаже дома с 1 этажом и составляют 49,41%, с 2 этажами продали 38,13 %. По продаже менее всего домов 3,5 этажа и составляют 0,04%.

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
data_cond = df['condition'].value_counts(sort=False)
data_cond
cond_val= data_cond.values
cond_ind = data_cond.index
cond_explode = [0,0,0,0.6,0.3]
colors = ["#ff7f0e", "#9467bd", "#d62728","#1f77b4", "#8c564b"]
plt.title("House condition")
plt.pie(cond_val, labels=cond_ind, radius = 1.5,
        startangle=-20, colors=colors,
        rotatelabels=True, explode = cond_explode,
        labeldistance=1.1, autopct='%.1f%%')
plt.title("House condition", bbox={'facecolor':'0.8', 'pad':5})
plt.show;

# %% [markdown]
# В плохом состоянии составляют 0,1% домов. наибольшее количество домов имеют оценку "3" и составляют 64,9%
