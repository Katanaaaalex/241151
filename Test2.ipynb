# %%
import pandas as pd

# %%
df = pd.read_csv('./kc_house_data.csv', sep=",", encoding="windows-1251")

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.sample()
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 1621  1310500550  20141220T000000  248000.0         4       2.25         2320
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1621      8760     1.0           0     0  ...      8      1160.0
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1621           1160      1966             0    98032  47.3627 -122.285
#
#       sqft_living15  sqft_lot15
# 1621           1970        8690
#
# [1 rows x 21 columns]

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# Первичный анализ данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# Минимальная цена дома:

# %%
df['price'].min()
# Out:
# 75000.0

# %% [markdown]
# Максимальная жилая площадь

# %%
df['sqft_living'].max()
# Out:
# 13540

# %%
df[['waterfront','view', 'sqft_above']].mean()
# Out:
# waterfront       0.007542
# view             0.234303
# sqft_above    1788.396095
# dtype: float64

# %%
df.describe(include = ['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# Количество непропущенных объектов 21613

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df.sort_values('price')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1149           670     43377     1.0           0     0  ...      3
# ...

# %% [markdown]
# 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
df[['sqft_living', 'sqft_lot']]
# Out:
#        sqft_living  sqft_lot
# 0             1180      5650
# 1             2570      7242
# 2              770     10000
# 3             1960      5000
# 4             1680      8080
# ...            ...       ...
# 21608         1530      1131
# 21609         2310      5813
# 21610         1020      1350
# 21611         1600      2388
# 21612         1020      1076
#
# [21613 rows x 2 columns]

# %%
df['share'] = df['sqft_living'] / df['sqft_lot']
df['share']
# Out:
# 0        0.208850
# 1        0.354874
# 2        0.077000
# 3        0.392000
# 4        0.207921
#            ...
# 21608    1.352785
# 21609    0.397385
# 21610    0.755556
# 21611    0.670017
# 21612    0.947955
# Name: share, Length: 21613, dtype: float64

# %%
df['share'].mean()
# Out:
# 0.3237447254204737

# %% [markdown]
# 3.3 Как много домов с разными этажами в данных?

# %%
df.sort_values('floors')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 9511   5412400180  20150417T000000   267500.0         3       2.50
# 9513   4037500110  20140506T000000   404000.0         4       1.75
# 9515   7856620210  20140808T000000   812500.0         4       2.75
# 9516    425200145  20140703T000000   265000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 18477  1346300150  20141020T000000  3300000.0         8       4.00
# 11594  3180100023  20150130T000000   544000.0         3       2.50
# 20308  1972200426  20140918T000000   525000.0         2       2.75
# 14885  8673400177  20150402T000000   525000.0         3       3.00
# 875    6306400140  20140612T000000  1095000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...      1180.0
# ...

# %% [markdown]
# 3.4 Насколько хорошие состояния у домов в данных?

# %%
df.sort_values('condition', ascending = False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 10729  2204500550  20140717T000000   425000.0         4       1.00
# 18075  5457800930  20140613T000000  1695000.0         2       2.25
# 15493  7147600225  20141113T000000   320000.0         6       2.75
# 1676   5700003985  20141029T000000  2250000.0         4       3.50
# 16951  7151700585  20141125T000000  1225000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 16942  5015001680  20140611T000000   427000.0         4       1.00
# 14987  9187200095  20141202T000000   432500.0         6       2.00
# 3004   9187200245  20141231T000000   441000.0         4       1.50
# 15712  3089000005  20140724T000000   150000.0         2       1.00
# 12306  2570600140  20150128T000000   196000.0         3       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 10729         1800     12485     1.0           0     0  ...       950.0
# ...

# %%
df[['condition']]
# Out:
#        condition
# 0              3
# 1              3
# 2              3
# 3              5
# 4              3
# ...          ...
# 21608          3
# 21609          3
# 21610          3
# 21611          3
# 21612          3
#
# [21613 rows x 1 columns]

# %% [markdown]
# 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df['yr_built'].min()
# Out:
# 1900

# %%
df['yr_built'].max()
# Out:
# 2015

# %% [markdown]
# 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df.bedrooms == 2][['price', 'bedrooms']]
df['price'].mean()
# Out:
# 540088.1417665294

# %% [markdown]
# 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df.price > 600000][['price', 'sqft_lot']]
df['sqft_lot'].mean()
# Out:
# 15106.967565816869

# %% [markdown]
# 4.3 Как много домов коснулся ремонт?

# %%
len(df[df['yr_renovated'] != 0])
# Out:
# 914

# %% [markdown]
# 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df[df['grade'] > 10]['price'].mean() - df[df['grade'] < 4]['price'].mean()
# Out:
# 1488885.1175298805
